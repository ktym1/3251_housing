# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('darkgrid')
sns.set_context('talk')

# %matplotlib inline

# %%
housing = pd.read_csv('Housing Dataset.csv')

housing.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# 0   2008        WD         Normal     208500
# 1   2007        WD         Normal     181500
# 2   2008        WD         Normal     223500
# 3   2006        WD        Abnorml     140000
# 4   2008        WD         Normal     250000
#
# [5 rows x 81 columns]

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# RoofMatl         1460 non-null object
# Exterior1st      1460 non-null object
# Exterior2nd      1460 non-null object
# MasVnrType       1452 non-null object
# MasVnrArea       1452 non-null float64
# ExterQual        1460 non-null object
# ExterCond        1460 non-null object
# Foundation       1460 non-null object
# BsmtQual         1423 non-null object
# BsmtCond         1423 non-null object
# BsmtExposure     1422 non-null object
# BsmtFinType1     1423 non-null object
# BsmtFinSF1       1460 non-null int64
# BsmtFinType2     1422 non-null object
# BsmtFinSF2       1460 non-null int64
# BsmtUnfSF        1460 non-null int64
# TotalBsmtSF      1460 non-null int64
# Heating          1460 non-null object
# HeatingQC        1460 non-null object
# CentralAir       1460 non-null object
# Electrical       1459 non-null object
# 1stFlrSF         1460 non-null int64
# 2ndFlrSF         1460 non-null int64
# LowQualFinSF     1460 non-null int64
# GrLivArea        1460 non-null int64
# BsmtFullBath     1460 non-null int64
# BsmtHalfBath     1460 non-null int64
# FullBath         1460 non-null int64
# HalfBath         1460 non-null int64
# BedroomAbvGr     1460 non-null int64
# KitchenAbvGr     1460 non-null int64
# KitchenQual      1460 non-null object
# TotRmsAbvGrd     1460 non-null int64
# Functional       1460 non-null object
# Fireplaces       1460 non-null int64
# FireplaceQu      770 non-null object
# GarageType       1379 non-null object
# GarageYrBlt      1379 non-null float64
# GarageFinish     1379 non-null object
# GarageCars       1460 non-null int64
# GarageArea       1460 non-null int64
# GarageQual       1379 non-null object
# GarageCond       1379 non-null object
# PavedDrive       1460 non-null object
# WoodDeckSF       1460 non-null int64
# OpenPorchSF      1460 non-null int64
# EnclosedPorch    1460 non-null int64
# 3SsnPorch        1460 non-null int64
# ScreenPorch      1460 non-null int64
# PoolArea         1460 non-null int64
# PoolQC           7 non-null object
# Fence            281 non-null object
# MiscFeature      54 non-null object
# MiscVal          1460 non-null int64
# MoSold           1460 non-null int64
# YrSold           1460 non-null int64
# SaleType         1460 non-null object
# SaleCondition    1460 non-null object
# SalePrice        1460 non-null int64
# dtypes: float64(3), int64(35), object(43)
# memory usage: 924.0+ KB

# %% [markdown]
# - 1460 houses in the dataset, majority of columns are fairly complete
# - Many of the features describe physical attributes of each home, for the purpose of statistical inference it might be ok to ignore these house-specific features and look at broader things like neighbourhood, overall condition, timeseries aspects
# - Sales Price is the dependent variable here, ultimately the target of any predictive model we make

# %%
housing['SalePrice'].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %% [markdown]
# - Mean is higher than median for sales price, indicating slight postive skew with outliers

# %%
plt.figure(figsize=(16,10))

housing['SalePrice'].hist(bins=30)

# %% [markdown]
# - Histogram indicates right skewed distribution

# %% [markdown]
# ## Timeseries Analysis
#
# Looking at Date Sold, Date Built
#
# - When were the houses in neighbourhoods built? Perhaps this could uncover some of the history of Boston's development
# - Quality of house when sold vs original time it was built
# - Age of a house before it's sold
# - When in the year are most houses sold? Any trends that could be useful to realtors?
# - Gentrifying? What neighbourhoods are on the rise?

# %% [markdown]
# ### Date Sold

# %%
housing[['MoSold', 'YrSold']].head()
# Out:
#    MoSold  YrSold
# 0       2    2008
# 1       5    2007
# 2       9    2008
# 3       2    2006
# 4      12    2008

# %%
import datetime

# %%
def date_sold(row):
    """combines MoSold and YrSold into a single date attribute"""
    y = row.YrSold
    m = row.MoSold
    datetime_obj = datetime.datetime.strptime("{} {}".format(m,y), "%m %Y")
    return datetime_obj

# %%
date_sold(housing.iloc[1])
# Out:
# datetime.datetime(2007, 5, 1, 0, 0)

# %%
housing['DateSold'] = housing.apply(date_sold, axis=1)

# %%
housing.DateSold.head()
# Out:
# 0   2008-02-01
# 1   2007-05-01
# 2   2008-09-01
# 3   2006-02-01
# 4   2008-12-01
# Name: DateSold, dtype: datetime64[ns]

# %%
housing_ts = housing.set_index(pd.DatetimeIndex(housing.DateSold))
housing_ts.reindex()
# Out:
#               Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# DateSold
# 2008-02-01     1          60       RL         65.0     8450   Pave   NaN
# 2007-05-01     2          20       RL         80.0     9600   Pave   NaN
# 2008-09-01     3          60       RL         68.0    11250   Pave   NaN
# 2006-02-01     4          70       RL         60.0     9550   Pave   NaN
# 2008-12-01     5          60       RL         84.0    14260   Pave   NaN
# 2009-10-01     6          50       RL         85.0    14115   Pave   NaN
# 2007-08-01     7          20       RL         75.0    10084   Pave   NaN
# 2009-11-01     8          60       RL          NaN    10382   Pave   NaN
# 2008-04-01     9          50       RM         51.0     6120   Pave   NaN
# 2008-01-01    10         190       RL         50.0     7420   Pave   NaN
# 2008-02-01    11          20       RL         70.0    11200   Pave   NaN
# 2006-07-01    12          60       RL         85.0    11924   Pave   NaN
# 2008-09-01    13          20       RL          NaN    12968   Pave   NaN
# 2007-08-01    14          20       RL         91.0    10652   Pave   NaN
# 2008-05-01    15          20       RL          NaN    10920   Pave   NaN
# 2007-07-01    16          45       RM         51.0     6120   Pave   NaN
# 2010-03-01    17          20       RL          NaN    11241   Pave   NaN
# 2006-10-01    18          90       RL         72.0    10791   Pave   NaN
# 2008-06-01    19          20       RL         66.0    13695   Pave   NaN
# 2009-05-01    20          20       RL         70.0     7560   Pave   NaN
# 2006-11-01    21          60       RL        101.0    14215   Pave   NaN
# 2007-06-01    22          45       RM         57.0     7449   Pave  Grvl
# 2008-09-01    23          20       RL         75.0     9742   Pave   NaN
# 2007-06-01    24         120       RM         44.0     4224   Pave   NaN
# 2010-05-01    25          20       RL          NaN     8246   Pave   NaN
# 2009-07-01    26          20       RL        110.0    14230   Pave   NaN
# 2010-05-01    27          20       RL         60.0     7200   Pave   NaN
# 2010-05-01    28          20       RL         98.0    11478   Pave   NaN
# 2006-12-01    29          20       RL         47.0    16321   Pave   NaN
# 2008-05-01    30          30       RM         60.0     6324   Pave   NaN
# ...          ...         ...      ...          ...      ...    ...   ...
# 2006-07-01  1431          60       RL         60.0    21930   Pave   NaN
# 2009-10-01  1432         120       RL          NaN     4928   Pave   NaN
# 2007-08-01  1433          30       RL         60.0    10800   Pave  Grvl
# 2008-05-01  1434          60       RL         93.0    10261   Pave   NaN
# 2006-05-01  1435          20       RL         80.0    17400   Pave   NaN
# 2008-07-01  1436          20       RL         80.0     8400   Pave   NaN
# 2007-05-01  1437          20       RL         60.0     9000   Pave   NaN
# 2008-11-01  1438          20       RL         96.0    12444   Pave   NaN
# 2010-04-01  1439          20       RM         90.0     7407   Pave   NaN
# 2007-11-01  1440          60       RL         80.0    11584   Pave   NaN
# 2008-09-01  1441          70       RL         79.0    11526   Pave   NaN
# 2008-05-01  1442         120       RM          NaN     4426   Pave   NaN
# 2009-04-01  1443          60       FV         85.0    11003   Pave   NaN
# 2009-05-01  1444          30       RL          NaN     8854   Pave   NaN
# 2007-11-01  1445          20       RL         63.0     8500   Pave   NaN
# 2007-05-01  1446          85       RL         70.0     8400   Pave   NaN
# 2010-04-01  1447          20       RL          NaN    26142   Pave   NaN
# 2007-12-01  1448          60       RL         80.0    10000   Pave   NaN
# 2007-05-01  1449          50       RL         70.0    11767   Pave   NaN
# 2006-08-01  1450         180       RM         21.0     1533   Pave   NaN
# 2009-09-01  1451          90       RL         60.0     9000   Pave   NaN
# 2009-05-01  1452          20       RL         78.0     9262   Pave   NaN
# 2006-05-01  1453         180       RM         35.0     3675   Pave   NaN
# 2006-07-01  1454          20       RL         90.0    17217   Pave   NaN
# 2009-10-01  1455          20       FV         62.0     7500   Pave  Pave
# 2007-08-01  1456          60       RL         62.0     7917   Pave   NaN
# 2010-02-01  1457          20       RL         85.0    13175   Pave   NaN
# 2010-05-01  1458          70       RL         66.0     9042   Pave   NaN
# 2010-04-01  1459          20       RL         68.0     9717   Pave   NaN
# 2008-06-01  1460          20       RL         75.0     9937   Pave   NaN
#
#            LotShape LandContour Utilities  ... PoolQC  Fence MiscFeature  \
# DateSold                                   ...
# 2008-02-01      Reg         Lvl    AllPub  ...    NaN    NaN         NaN
# 2007-05-01      Reg         Lvl    AllPub  ...    NaN    NaN         NaN
# 2008-09-01      IR1         Lvl    AllPub  ...    NaN    NaN         NaN
# 2006-02-01      IR1         Lvl    AllPub  ...    NaN    NaN         NaN
# 2008-12-01      IR1         Lvl    AllPub  ...    NaN    NaN         NaN
# 2009-10-01      IR1         Lvl    AllPub  ...    NaN  MnPrv        Shed
# 2007-08-01      Reg         Lvl    AllPub  ...    NaN    NaN         NaN
# 2009-11-01      IR1         Lvl    AllPub  ...    NaN    NaN        Shed
# 2008-04-01      Reg         Lvl    AllPub  ...    NaN    NaN         NaN
# 2008-01-01      Reg         Lvl    AllPub  ...    NaN    NaN         NaN
# 2008-02-01      Reg         Lvl    AllPub  ...    NaN    NaN         NaN
# 2006-07-01      IR1         Lvl    AllPub  ...    NaN    NaN         NaN
# 2008-09-01      IR2         Lvl    AllPub  ...    NaN    NaN         NaN
# 2007-08-01      IR1         Lvl    AllPub  ...    NaN    NaN         NaN
# 2008-05-01      IR1         Lvl    AllPub  ...    NaN   GdWo         NaN
# 2007-07-01      Reg         Lvl    AllPub  ...    NaN  GdPrv         NaN
# 2010-03-01      IR1         Lvl    AllPub  ...    NaN    NaN        Shed
# 2006-10-01      Reg         Lvl    AllPub  ...    NaN    NaN        Shed
# 2008-06-01      Reg         Lvl    AllPub  ...    NaN    NaN         NaN
# 2009-05-01      Reg         Lvl    AllPub  ...    NaN  MnPrv         NaN
# 2006-11-01      IR1         Lvl    AllPub  ...    NaN    NaN         NaN
# 2007-06-01      Reg         Bnk    AllPub  ...    NaN  GdPrv         NaN
# 2008-09-01      Reg         Lvl    AllPub  ...    NaN    NaN         NaN
# 2007-06-01      Reg         Lvl    AllPub  ...    NaN    NaN         NaN
# 2010-05-01      IR1         Lvl    AllPub  ...    NaN  MnPrv         NaN
# 2009-07-01      Reg         Lvl    AllPub  ...    NaN    NaN         NaN
# 2010-05-01      Reg         Lvl    AllPub  ...    NaN    NaN         NaN
# 2010-05-01      Reg         Lvl    AllPub  ...    NaN    NaN         NaN
# 2006-12-01      IR1         Lvl    AllPub  ...    NaN    NaN         NaN
# 2008-05-01      IR1         Lvl    AllPub  ...    NaN    NaN         NaN
# ...             ...         ...       ...  ...    ...    ...         ...
# 2006-07-01      IR3         Lvl    AllPub  ...    NaN    NaN         NaN
# 2009-10-01      IR1         Lvl    AllPub  ...    NaN    NaN         NaN
# 2007-08-01      Reg         Lvl    AllPub  ...    NaN    NaN         NaN
# 2008-05-01      IR1         Lvl    AllPub  ...    NaN    NaN         NaN
# 2006-05-01      Reg         Low    AllPub  ...    NaN    NaN         NaN
# 2008-07-01      Reg         Lvl    AllPub  ...    NaN  GdPrv         NaN
# 2007-05-01      Reg         Lvl    AllPub  ...    NaN   GdWo         NaN
# 2008-11-01      Reg         Lvl    AllPub  ...    NaN    NaN         NaN
# 2010-04-01      Reg         Lvl    AllPub  ...    NaN  MnPrv         NaN
# 2007-11-01      Reg         Lvl    AllPub  ...    NaN    NaN         NaN
# 2008-09-01      IR1         Bnk    AllPub  ...    NaN    NaN         NaN
# 2008-05-01      Reg         Lvl    AllPub  ...    NaN    NaN         NaN
# 2009-04-01      Reg         Lvl    AllPub  ...    NaN    NaN         NaN
# 2009-05-01      Reg         Lvl    AllPub  ...    NaN    NaN         NaN
# 2007-11-01      Reg         Lvl    AllPub  ...    NaN    NaN         NaN
# 2007-05-01      Reg         Lvl    AllPub  ...    NaN    NaN         NaN
# 2010-04-01      IR1         Lvl    AllPub  ...    NaN    NaN         NaN
# 2007-12-01      Reg         Lvl    AllPub  ...    NaN    NaN         NaN
# 2007-05-01      Reg         Lvl    AllPub  ...    NaN   GdWo         NaN
# 2006-08-01      Reg         Lvl    AllPub  ...    NaN    NaN         NaN
# 2009-09-01      Reg         Lvl    AllPub  ...    NaN    NaN         NaN
# 2009-05-01      Reg         Lvl    AllPub  ...    NaN    NaN         NaN
# 2006-05-01      Reg         Lvl    AllPub  ...    NaN    NaN         NaN
# 2006-07-01      Reg         Lvl    AllPub  ...    NaN    NaN         NaN
# 2009-10-01      Reg         Lvl    AllPub  ...    NaN    NaN         NaN
# 2007-08-01      Reg         Lvl    AllPub  ...    NaN    NaN         NaN
# 2010-02-01      Reg         Lvl    AllPub  ...    NaN  MnPrv         NaN
# 2010-05-01      Reg         Lvl    AllPub  ...    NaN  GdPrv        Shed
# 2010-04-01      Reg         Lvl    AllPub  ...    NaN    NaN         NaN
# 2008-06-01      Reg         Lvl    AllPub  ...    NaN    NaN         NaN
#
#            MiscVal MoSold YrSold SaleType  SaleCondition  SalePrice   DateSold
# DateSold
# 2008-02-01       0      2   2008       WD         Normal     208500 2008-02-01
# 2007-05-01       0      5   2007       WD         Normal     181500 2007-05-01
# 2008-09-01       0      9   2008       WD         Normal     223500 2008-09-01
# 2006-02-01       0      2   2006       WD        Abnorml     140000 2006-02-01
# 2008-12-01       0     12   2008       WD         Normal     250000 2008-12-01
# 2009-10-01     700     10   2009       WD         Normal     143000 2009-10-01
# 2007-08-01       0      8   2007       WD         Normal     307000 2007-08-01
# 2009-11-01     350     11   2009       WD         Normal     200000 2009-11-01
# 2008-04-01       0      4   2008       WD        Abnorml     129900 2008-04-01
# 2008-01-01       0      1   2008       WD         Normal     118000 2008-01-01
# 2008-02-01       0      2   2008       WD         Normal     129500 2008-02-01
# 2006-07-01       0      7   2006      New        Partial     345000 2006-07-01
# 2008-09-01       0      9   2008       WD         Normal     144000 2008-09-01
# 2007-08-01       0      8   2007      New        Partial     279500 2007-08-01
# 2008-05-01       0      5   2008       WD         Normal     157000 2008-05-01
# 2007-07-01       0      7   2007       WD         Normal     132000 2007-07-01
# 2010-03-01     700      3   2010       WD         Normal     149000 2010-03-01
# 2006-10-01     500     10   2006       WD         Normal      90000 2006-10-01
# 2008-06-01       0      6   2008       WD         Normal     159000 2008-06-01
# 2009-05-01       0      5   2009      COD        Abnorml     139000 2009-05-01
# 2006-11-01       0     11   2006      New        Partial     325300 2006-11-01
# 2007-06-01       0      6   2007       WD         Normal     139400 2007-06-01
# 2008-09-01       0      9   2008       WD         Normal     230000 2008-09-01
# 2007-06-01       0      6   2007       WD         Normal     129900 2007-06-01
# 2010-05-01       0      5   2010       WD         Normal     154000 2010-05-01
# 2009-07-01       0      7   2009       WD         Normal     256300 2009-07-01
# 2010-05-01       0      5   2010       WD         Normal     134800 2010-05-01
# 2010-05-01       0      5   2010       WD         Normal     306000 2010-05-01
# 2006-12-01       0     12   2006       WD         Normal     207500 2006-12-01
# 2008-05-01       0      5   2008       WD         Normal      68500 2008-05-01
# ...            ...    ...    ...      ...            ...        ...        ...
# 2006-07-01       0      7   2006       WD         Normal     192140 2006-07-01
# 2009-10-01       0     10   2009       WD         Normal     143750 2009-10-01
# 2007-08-01       0      8   2007       WD         Normal      64500 2007-08-01
# 2008-05-01       0      5   2008       WD         Normal     186500 2008-05-01
# 2006-05-01       0      5   2006       WD         Normal     160000 2006-05-01
# 2008-07-01       0      7   2008      COD        Abnorml     174000 2008-07-01
# 2007-05-01       0      5   2007       WD         Normal     120500 2007-05-01
# 2008-11-01       0     11   2008      New        Partial     394617 2008-11-01
# 2010-04-01       0      4   2010       WD         Normal     149700 2010-04-01
# 2007-11-01       0     11   2007       WD         Normal     197000 2007-11-01
# 2008-09-01       0      9   2008       WD         Normal     191000 2008-09-01
# 2008-05-01       0      5   2008       WD         Normal     149300 2008-05-01
# 2009-04-01       0      4   2009       WD         Normal     310000 2009-04-01
# 2009-05-01       0      5   2009       WD         Normal     121000 2009-05-01
# 2007-11-01       0     11   2007       WD         Normal     179600 2007-11-01
# 2007-05-01       0      5   2007       WD         Normal     129000 2007-05-01
# 2010-04-01       0      4   2010       WD         Normal     157900 2010-04-01
# 2007-12-01       0     12   2007       WD         Normal     240000 2007-12-01
# 2007-05-01       0      5   2007       WD         Normal     112000 2007-05-01
# 2006-08-01       0      8   2006       WD        Abnorml      92000 2006-08-01
# 2009-09-01       0      9   2009       WD         Normal     136000 2009-09-01
# 2009-05-01       0      5   2009      New        Partial     287090 2009-05-01
# 2006-05-01       0      5   2006       WD         Normal     145000 2006-05-01
# 2006-07-01       0      7   2006       WD        Abnorml      84500 2006-07-01
# 2009-10-01       0     10   2009       WD         Normal     185000 2009-10-01
# 2007-08-01       0      8   2007       WD         Normal     175000 2007-08-01
# 2010-02-01       0      2   2010       WD         Normal     210000 2010-02-01
# 2010-05-01    2500      5   2010       WD         Normal     266500 2010-05-01
# 2010-04-01       0      4   2010       WD         Normal     142125 2010-04-01
# 2008-06-01       0      6   2008       WD         Normal     147500 2008-06-01
#
# [1460 rows x 82 columns]

# %%
plt.figure(figsize=(16,10))

housing_ts.resample('M').Id.count().plot()

# %% [markdown]
# - Very clear indication of seasonality when it comes to housing sales, most houses are sold during the middle of the year

# %%
housing_ts.groupby(['MoSold']).count().Id.sort_values(ascending=False)
# Out:
# MoSold
# 6     253
# 7     234
# 5     204
# 4     141
# 8     122
# 3     106
# 10     89
# 11     79
# 9      63
# 12     59
# 1      58
# 2      52
# Name: Id, dtype: int64

# %% [markdown]
# - May, June, July (Months 5,6,7) are when most houses get sold
# - The beginning/end of each year are when the least houses are sold

# %% [markdown]
# - Is avg. sale price affected by seasonality as well? Do you get more if you sell a house at a specific point in time?
# - Also, looking at how the market prices have fluctuated over time:

# %%
plt.figure(figsize=(16,10))

housing_ts.resample('M').SalePrice.mean().plot(label="mean")
housing_ts.resample('M').SalePrice.median().plot(label="median")

plt.legend()

# %% [markdown]
# - No clear pattern of seasonality here
# - Sales prices seems to be trending slightly downwards over time

# %%
plt.figure(figsize=(16,10))

housing_ts.resample('Y').SalePrice.mean().plot(label="mean")
housing_ts.resample('Y').SalePrice.median().plot(label="median")

plt.legend()

# %% [markdown]
# - Perhaps due to 2009 housing crisis?

# %% [markdown]
# ### Year Built, House Age

# %% [markdown]
# - Which neighbourhoods grew over time? (houses built)

# %%
plt.figure(figsize=(16,10))

housing_ts['YearBuilt'].hist(bins=30)

# %% [markdown]
# - Distribution of houses built is multimodal, peaks in the 1960s-80s and 1990s-2000s
# - What caused these spurs of development over time?
# - Periods of economic growth/stagnation in Boston?

# %%
housing_ts['HouseAge'] = housing_ts.YrSold - housing_ts.YearBuilt

plt.figure(figsize=(16,10))
housing_ts.HouseAge.hist(bins=30)

# %% [markdown]
# - Somewhat exponential distribution of housing ages before they're sold
# - Most of the houses sold are very new, but there's a good portion that get sold after they're 20-60 years old
# - Could do statistical inference here to find parameters for exponential distribution of housing ages, using MCMC/PyMC3 model
# - Is there a correlation b/w house age and house condition at time of sale?
# - Look into year of Remodeling too

# %%
plt.figure(figsize=(16,10))

plt.scatter(housing_ts.HouseAge, housing_ts.SalePrice)
plt.ylabel("Sale Price (USD)")
plt.xlabel("Age in Years at Time of Sale")
# Out:
# Text(0.5, 0, 'Age in Years at Time of Sale')

# %%
housing_ts[['HouseAge', 'SalePrice']].corr()
# Out:
#            HouseAge  SalePrice
# HouseAge    1.00000   -0.52335
# SalePrice  -0.52335    1.00000

# %% [markdown]
# - Moderate negative relationship between Sale Price and age of house at time of sale

# %% [markdown]
# ### The growth of different neighbourhoods over time

# %% [markdown]
# - Lets see the rates at which houses were built in each of Boston's neighbourhoods

# %%
housing_ts.Neighborhood.unique()
# Out:
# array(['CollgCr', 'Veenker', 'Crawfor', 'NoRidge', 'Mitchel', 'Somerst',
#        'NWAmes', 'OldTown', 'BrkSide', 'Sawyer', 'NridgHt', 'NAmes',
#        'SawyerW', 'IDOTRR', 'MeadowV', 'Edwards', 'Timber', 'Gilbert',
#        'StoneBr', 'ClearCr', 'NPkVill', 'Blmngtn', 'BrDale', 'SWISU',
#        'Blueste'], dtype=object)

# %% [markdown]
# Change neighborhood abbreviations to actual names

# %%
neighbourhood_names = {
    "Blmngtn": "Bloomington Heights",
    "Blueste": "Bluestem",
    "BrDale": "Briardale",
    "BrkSide": "Brookside",
    "ClearCr": "Clear Creek",
    "CollgCr": "College Creek",
    "Crawfor": "Crawford",
    "Edwards": "Edwards",
    "Gilbert": "Gilbert",
    "IDOTRR": "Iowa DOT and Rail Road",
    "MeadowV": "Meadow Village",
    "Mitchel": "Mitchell",
    "NAmes": "North Ames",
    "NoRidge": "Northridge",
    "NPkVill": "Northpark Villa",
    "NridgHt": "Northridge Heights",
    "NWAmes": "Northwest Ames",
    "OldTown": "Old Town",
    "SWISU": "South & West of Iowa State University",
    "Sawyer": "Sawyer",
    "SawyerW": "Sawyer West",
    "Somerst": "Somerset",
    "StoneBr": "Stone Brook",
    "Timber": "Timberland",
    "Veenker": "Veenker"
}

housing_ts.Neighborhood = housing_ts.Neighborhood.apply(lambda x: neighbourhood_names[x])

# %% [markdown]
# - First let's see the size of different neighbourhoods

# %%
neighbourhood_size = housing_ts.groupby('Neighborhood').Id.count()

plt.figure(figsize=(16,10))
sns.barplot(y=neighbourhood_size.index, x=neighbourhood_size)
plt.xlabel("# of Houses", labelpad=20)
# Out:
# Text(0.5, 0, '# of Houses')

# %% [markdown]
# - North Ames, College Creek, Old Town have the most houses

# %% [markdown]
# Let's also check the median sale price per neighbourhood:

# %%
neighbourhood_median_price = housing_ts.groupby('Neighborhood').SalePrice.median()

plt.figure(figsize=(16,10))
sns.barplot(y=neighbourhood_median_price.index, x=neighbourhood_median_price)
plt.xlabel("Median Sale Price", labelpad=20)
# Out:
# Text(0.5, 0, 'Median Sale Price')

# %% [markdown]
# - Northridge area seems to be the pricey part of town, with Stone Brook, Timberland, Somerset, and Veenker following up
# - Meadow Village and Iowa DOT seem to be cheap parts

# %% [markdown]
# Moving onto the number of houses built in each area over time:

# %%
housing_ts.YearBuilt = housing_ts.YearBuilt.apply(lambda x: datetime.datetime.strptime(str(x), '%Y'))

# %%
housing_built_ts = housing_ts.set_index(pd.DatetimeIndex(housing_ts.YearBuilt))
housing_built_ts.reindex()
# Out:
#               Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley  \
# YearBuilt
# 2003-01-01     1          60       RL         65.0     8450   Pave   NaN
# 1976-01-01     2          20       RL         80.0     9600   Pave   NaN
# 2001-01-01     3          60       RL         68.0    11250   Pave   NaN
# 1915-01-01     4          70       RL         60.0     9550   Pave   NaN
# 2000-01-01     5          60       RL         84.0    14260   Pave   NaN
# 1993-01-01     6          50       RL         85.0    14115   Pave   NaN
# 2004-01-01     7          20       RL         75.0    10084   Pave   NaN
# 1973-01-01     8          60       RL          NaN    10382   Pave   NaN
# 1931-01-01     9          50       RM         51.0     6120   Pave   NaN
# 1939-01-01    10         190       RL         50.0     7420   Pave   NaN
# 1965-01-01    11          20       RL         70.0    11200   Pave   NaN
# 2005-01-01    12          60       RL         85.0    11924   Pave   NaN
# 1962-01-01    13          20       RL          NaN    12968   Pave   NaN
# 2006-01-01    14          20       RL         91.0    10652   Pave   NaN
# 1960-01-01    15          20       RL          NaN    10920   Pave   NaN
# 1929-01-01    16          45       RM         51.0     6120   Pave   NaN
# 1970-01-01    17          20       RL          NaN    11241   Pave   NaN
# 1967-01-01    18          90       RL         72.0    10791   Pave   NaN
# 2004-01-01    19          20       RL         66.0    13695   Pave   NaN
# 1958-01-01    20          20       RL         70.0     7560   Pave   NaN
# 2005-01-01    21          60       RL        101.0    14215   Pave   NaN
# 1930-01-01    22          45       RM         57.0     7449   Pave  Grvl
# 2002-01-01    23          20       RL         75.0     9742   Pave   NaN
# 1976-01-01    24         120       RM         44.0     4224   Pave   NaN
# 1968-01-01    25          20       RL          NaN     8246   Pave   NaN
# 2007-01-01    26          20       RL        110.0    14230   Pave   NaN
# 1951-01-01    27          20       RL         60.0     7200   Pave   NaN
# 2007-01-01    28          20       RL         98.0    11478   Pave   NaN
# 1957-01-01    29          20       RL         47.0    16321   Pave   NaN
# 1927-01-01    30          30       RM         60.0     6324   Pave   NaN
# ...          ...         ...      ...          ...      ...    ...   ...
# 2005-01-01  1431          60       RL         60.0    21930   Pave   NaN
# 1976-01-01  1432         120       RL          NaN     4928   Pave   NaN
# 1927-01-01  1433          30       RL         60.0    10800   Pave  Grvl
# 2000-01-01  1434          60       RL         93.0    10261   Pave   NaN
# 1977-01-01  1435          20       RL         80.0    17400   Pave   NaN
# 1962-01-01  1436          20       RL         80.0     8400   Pave   NaN
# 1971-01-01  1437          20       RL         60.0     9000   Pave   NaN
# 2008-01-01  1438          20       RL         96.0    12444   Pave   NaN
# 1957-01-01  1439          20       RM         90.0     7407   Pave   NaN
# 1979-01-01  1440          60       RL         80.0    11584   Pave   NaN
# 1922-01-01  1441          70       RL         79.0    11526   Pave   NaN
# 2004-01-01  1442         120       RM          NaN     4426   Pave   NaN
# 2008-01-01  1443          60       FV         85.0    11003   Pave   NaN
# 1916-01-01  1444          30       RL          NaN     8854   Pave   NaN
# 2004-01-01  1445          20       RL         63.0     8500   Pave   NaN
# 1966-01-01  1446          85       RL         70.0     8400   Pave   NaN
# 1962-01-01  1447          20       RL          NaN    26142   Pave   NaN
# 1995-01-01  1448          60       RL         80.0    10000   Pave   NaN
# 1910-01-01  1449          50       RL         70.0    11767   Pave   NaN
# 1970-01-01  1450         180       RM         21.0     1533   Pave   NaN
# 1974-01-01  1451          90       RL         60.0     9000   Pave   NaN
# 2008-01-01  1452          20       RL         78.0     9262   Pave   NaN
# 2005-01-01  1453         180       RM         35.0     3675   Pave   NaN
# 2006-01-01  1454          20       RL         90.0    17217   Pave   NaN
# 2004-01-01  1455          20       FV         62.0     7500   Pave  Pave
# 1999-01-01  1456          60       RL         62.0     7917   Pave   NaN
# 1978-01-01  1457          20       RL         85.0    13175   Pave   NaN
# 1941-01-01  1458          70       RL         66.0     9042   Pave   NaN
# 1950-01-01  1459          20       RL         68.0     9717   Pave   NaN
# 1965-01-01  1460          20       RL         75.0     9937   Pave   NaN
#
#            LotShape LandContour Utilities  ...  Fence MiscFeature MiscVal  \
# YearBuilt                                  ...
# 2003-01-01      Reg         Lvl    AllPub  ...    NaN         NaN       0
# 1976-01-01      Reg         Lvl    AllPub  ...    NaN         NaN       0
# 2001-01-01      IR1         Lvl    AllPub  ...    NaN         NaN       0
# 1915-01-01      IR1         Lvl    AllPub  ...    NaN         NaN       0
# 2000-01-01      IR1         Lvl    AllPub  ...    NaN         NaN       0
# 1993-01-01      IR1         Lvl    AllPub  ...  MnPrv        Shed     700
# 2004-01-01      Reg         Lvl    AllPub  ...    NaN         NaN       0
# 1973-01-01      IR1         Lvl    AllPub  ...    NaN        Shed     350
# 1931-01-01      Reg         Lvl    AllPub  ...    NaN         NaN       0
# 1939-01-01      Reg         Lvl    AllPub  ...    NaN         NaN       0
# 1965-01-01      Reg         Lvl    AllPub  ...    NaN         NaN       0
# 2005-01-01      IR1         Lvl    AllPub  ...    NaN         NaN       0
# 1962-01-01      IR2         Lvl    AllPub  ...    NaN         NaN       0
# 2006-01-01      IR1         Lvl    AllPub  ...    NaN         NaN       0
# 1960-01-01      IR1         Lvl    AllPub  ...   GdWo         NaN       0
# 1929-01-01      Reg         Lvl    AllPub  ...  GdPrv         NaN       0
# 1970-01-01      IR1         Lvl    AllPub  ...    NaN        Shed     700
# 1967-01-01      Reg         Lvl    AllPub  ...    NaN        Shed     500
# 2004-01-01      Reg         Lvl    AllPub  ...    NaN         NaN       0
# 1958-01-01      Reg         Lvl    AllPub  ...  MnPrv         NaN       0
# 2005-01-01      IR1         Lvl    AllPub  ...    NaN         NaN       0
# 1930-01-01      Reg         Bnk    AllPub  ...  GdPrv         NaN       0
# 2002-01-01      Reg         Lvl    AllPub  ...    NaN         NaN       0
# 1976-01-01      Reg         Lvl    AllPub  ...    NaN         NaN       0
# 1968-01-01      IR1         Lvl    AllPub  ...  MnPrv         NaN       0
# 2007-01-01      Reg         Lvl    AllPub  ...    NaN         NaN       0
# 1951-01-01      Reg         Lvl    AllPub  ...    NaN         NaN       0
# 2007-01-01      Reg         Lvl    AllPub  ...    NaN         NaN       0
# 1957-01-01      IR1         Lvl    AllPub  ...    NaN         NaN       0
# 1927-01-01      IR1         Lvl    AllPub  ...    NaN         NaN       0
# ...             ...         ...       ...  ...    ...         ...     ...
# 2005-01-01      IR3         Lvl    AllPub  ...    NaN         NaN       0
# 1976-01-01      IR1         Lvl    AllPub  ...    NaN         NaN       0
# 1927-01-01      Reg         Lvl    AllPub  ...    NaN         NaN       0
# 2000-01-01      IR1         Lvl    AllPub  ...    NaN         NaN       0
# 1977-01-01      Reg         Low    AllPub  ...    NaN         NaN       0
# 1962-01-01      Reg         Lvl    AllPub  ...  GdPrv         NaN       0
# 1971-01-01      Reg         Lvl    AllPub  ...   GdWo         NaN       0
# 2008-01-01      Reg         Lvl    AllPub  ...    NaN         NaN       0
# 1957-01-01      Reg         Lvl    AllPub  ...  MnPrv         NaN       0
# 1979-01-01      Reg         Lvl    AllPub  ...    NaN         NaN       0
# 1922-01-01      IR1         Bnk    AllPub  ...    NaN         NaN       0
# 2004-01-01      Reg         Lvl    AllPub  ...    NaN         NaN       0
# 2008-01-01      Reg         Lvl    AllPub  ...    NaN         NaN       0
# 1916-01-01      Reg         Lvl    AllPub  ...    NaN         NaN       0
# 2004-01-01      Reg         Lvl    AllPub  ...    NaN         NaN       0
# 1966-01-01      Reg         Lvl    AllPub  ...    NaN         NaN       0
# 1962-01-01      IR1         Lvl    AllPub  ...    NaN         NaN       0
# 1995-01-01      Reg         Lvl    AllPub  ...    NaN         NaN       0
# 1910-01-01      Reg         Lvl    AllPub  ...   GdWo         NaN       0
# 1970-01-01      Reg         Lvl    AllPub  ...    NaN         NaN       0
# 1974-01-01      Reg         Lvl    AllPub  ...    NaN         NaN       0
# 2008-01-01      Reg         Lvl    AllPub  ...    NaN         NaN       0
# 2005-01-01      Reg         Lvl    AllPub  ...    NaN         NaN       0
# 2006-01-01      Reg         Lvl    AllPub  ...    NaN         NaN       0
# 2004-01-01      Reg         Lvl    AllPub  ...    NaN         NaN       0
# 1999-01-01      Reg         Lvl    AllPub  ...    NaN         NaN       0
# 1978-01-01      Reg         Lvl    AllPub  ...  MnPrv         NaN       0
# 1941-01-01      Reg         Lvl    AllPub  ...  GdPrv        Shed    2500
# 1950-01-01      Reg         Lvl    AllPub  ...    NaN         NaN       0
# 1965-01-01      Reg         Lvl    AllPub  ...    NaN         NaN       0
#
#            MoSold YrSold SaleType SaleCondition  SalePrice   DateSold HouseAge
# YearBuilt
# 2003-01-01      2   2008       WD        Normal     208500 2008-02-01        5
# 1976-01-01      5   2007       WD        Normal     181500 2007-05-01       31
# 2001-01-01      9   2008       WD        Normal     223500 2008-09-01        7
# 1915-01-01      2   2006       WD       Abnorml     140000 2006-02-01       91
# 2000-01-01     12   2008       WD        Normal     250000 2008-12-01        8
# 1993-01-01     10   2009       WD        Normal     143000 2009-10-01       16
# 2004-01-01      8   2007       WD        Normal     307000 2007-08-01        3
# 1973-01-01     11   2009       WD        Normal     200000 2009-11-01       36
# 1931-01-01      4   2008       WD       Abnorml     129900 2008-04-01       77
# 1939-01-01      1   2008       WD        Normal     118000 2008-01-01       69
# 1965-01-01      2   2008       WD        Normal     129500 2008-02-01       43
# 2005-01-01      7   2006      New       Partial     345000 2006-07-01        1
# 1962-01-01      9   2008       WD        Normal     144000 2008-09-01       46
# 2006-01-01      8   2007      New       Partial     279500 2007-08-01        1
# 1960-01-01      5   2008       WD        Normal     157000 2008-05-01       48
# 1929-01-01      7   2007       WD        Normal     132000 2007-07-01       78
# 1970-01-01      3   2010       WD        Normal     149000 2010-03-01       40
# 1967-01-01     10   2006       WD        Normal      90000 2006-10-01       39
# 2004-01-01      6   2008       WD        Normal     159000 2008-06-01        4
# 1958-01-01      5   2009      COD       Abnorml     139000 2009-05-01       51
# 2005-01-01     11   2006      New       Partial     325300 2006-11-01        1
# 1930-01-01      6   2007       WD        Normal     139400 2007-06-01       77
# 2002-01-01      9   2008       WD        Normal     230000 2008-09-01        6
# 1976-01-01      6   2007       WD        Normal     129900 2007-06-01       31
# 1968-01-01      5   2010       WD        Normal     154000 2010-05-01       42
# 2007-01-01      7   2009       WD        Normal     256300 2009-07-01        2
# 1951-01-01      5   2010       WD        Normal     134800 2010-05-01       59
# 2007-01-01      5   2010       WD        Normal     306000 2010-05-01        3
# 1957-01-01     12   2006       WD        Normal     207500 2006-12-01       49
# 1927-01-01      5   2008       WD        Normal      68500 2008-05-01       81
# ...           ...    ...      ...           ...        ...        ...      ...
# 2005-01-01      7   2006       WD        Normal     192140 2006-07-01        1
# 1976-01-01     10   2009       WD        Normal     143750 2009-10-01       33
# 1927-01-01      8   2007       WD        Normal      64500 2007-08-01       80
# 2000-01-01      5   2008       WD        Normal     186500 2008-05-01        8
# 1977-01-01      5   2006       WD        Normal     160000 2006-05-01       29
# 1962-01-01      7   2008      COD       Abnorml     174000 2008-07-01       46
# 1971-01-01      5   2007       WD        Normal     120500 2007-05-01       36
# 2008-01-01     11   2008      New       Partial     394617 2008-11-01        0
# 1957-01-01      4   2010       WD        Normal     149700 2010-04-01       53
# 1979-01-01     11   2007       WD        Normal     197000 2007-11-01       28
# 1922-01-01      9   2008       WD        Normal     191000 2008-09-01       86
# 2004-01-01      5   2008       WD        Normal     149300 2008-05-01        4
# 2008-01-01      4   2009       WD        Normal     310000 2009-04-01        1
# 1916-01-01      5   2009       WD        Normal     121000 2009-05-01       93
# 2004-01-01     11   2007       WD        Normal     179600 2007-11-01        3
# 1966-01-01      5   2007       WD        Normal     129000 2007-05-01       41
# 1962-01-01      4   2010       WD        Normal     157900 2010-04-01       48
# 1995-01-01     12   2007       WD        Normal     240000 2007-12-01       12
# 1910-01-01      5   2007       WD        Normal     112000 2007-05-01       97
# 1970-01-01      8   2006       WD       Abnorml      92000 2006-08-01       36
# 1974-01-01      9   2009       WD        Normal     136000 2009-09-01       35
# 2008-01-01      5   2009      New       Partial     287090 2009-05-01        1
# 2005-01-01      5   2006       WD        Normal     145000 2006-05-01        1
# 2006-01-01      7   2006       WD       Abnorml      84500 2006-07-01        0
# 2004-01-01     10   2009       WD        Normal     185000 2009-10-01        5
# 1999-01-01      8   2007       WD        Normal     175000 2007-08-01        8
# 1978-01-01      2   2010       WD        Normal     210000 2010-02-01       32
# 1941-01-01      5   2010       WD        Normal     266500 2010-05-01       69
# 1950-01-01      4   2010       WD        Normal     142125 2010-04-01       60
# 1965-01-01      6   2008       WD        Normal     147500 2008-06-01       43
#
# [1460 rows x 83 columns]

# %% [markdown]
# First, let's see the development of all housing in Boston over time:

# %%
plt.figure(figsize=(16,10))

housing_built_ts['Count'] = 1
housing_built_ts.sort_index().Count.cumsum().plot()

# %% [markdown]
# - Spikes in development between 1950-1980 and 1990 onwards
#
# Separating into individual neighbourhoods:

# %%
palette = ["#a14a77", "#62bf4b", "#9f56c7", "#a1b837", "#5e6ed9", "#c0ab39", "#d055b6",
           "#4dc381", "#dd4b85", "#508f36", "#c98fd2", "#dc9636", "#5e99d5", "#ca5e2b", 
           "#43c4c4", "#d43e41", "#5bae8a", "#a74949", "#33784a", "#745fa2", "#a7b26b",
           "#e28085", "#697329", "#da9669", "#91692d"]

import warnings
warnings.filterwarnings('ignore')

plt.figure(figsize=(24, 16))

for neighbourhood, color in zip(housing_built_ts.Neighborhood.unique(), palette):
    neighbourhood_data = housing_built_ts[housing_built_ts.Neighborhood == neighbourhood]
    houses_cumsum = neighbourhood_data.sort_index().Count.cumsum()
    plt.plot(houses_cumsum.index, houses_cumsum.values, label=neighbourhood, c=color)
    plt.annotate(neighbourhood, (houses_cumsum.index[-1], houses_cumsum.values[-1]), fontsize=16)

#plt.legend()

# %% [markdown]
# ### Comparing Sale Price of New vs. Old Houses
#
# Let's divide the houses into new and old, using 1990 as the dividing point between the two groups. 1990 was chosen since it was the beginning of a surge in houses being built (see two plots above)

# %%
housing_built_ts.index < '1990-01-01'
# Out:
# array([False,  True, False, ...,  True,  True,  True])

# %%
new_houses = housing_built_ts[housing_built_ts.index >= '1990-01-01']
old_houses = housing_built_ts[housing_built_ts.index <= '1990-01-01']

# %%
n_new = len(new_houses)
n_old = len(old_houses)

print("# of new houses: {}\n# of old houses: {}".format(n_new, n_old))
# Out:
# # of new houses: 551
# # of old houses: 921

# %%
plt.figure(figsize=(16,10))

new_houses.SalePrice.hist(bins=30, alpha=0.5, label='new')
old_houses.SalePrice.hist(bins=30, alpha=0.5, label='old')

plt.legend()

# %% [markdown]
# - A lot of overlap between the two groups, but still some slight difference

# %%
plt.figure(figsize=(16,10))

plt.boxplot([new_houses.SalePrice, old_houses.SalePrice], labels=['new', 'old'])
plt.show()

# %% [markdown]
# **Now that we've examined the difference in means between new and old homes, we can attempt using a Welch's T-Test**
#
# HO: A home being new or old (pre/post 1990) has no significant impact on its price<br>
# HA: There is a statistically significant difference between the sales prices of new and old homes
#
# We'll test this at a significance level of 0.1

# %%
significance_level = 0.1

# %%
new_house_array = np.array(new_houses.SalePrice)
old_house_array = np.array(old_houses.SalePrice)

# %%
new_mean = new_house_array.mean()
old_mean = old_house_array.mean()

print("Mean Sales Price for New Homes: {}\nMean Sales Price for Old Homes: {}".format(new_mean, old_mean))
# Out:
# Mean Sales Price for New Homes: 238287.26497277676
# Mean Sales Price for Old Homes: 147121.8707926167

# %%
new_var = new_house_array.var(ddof=1)
old_var = old_house_array.var(ddof=1)

# %%
se_new = (new_var/n_new)
se_old = (old_var/n_old)

t = (new_mean - old_mean)/(se_new + se_old)
t
# Out:
# 0.005670919769804672

# %%
df = (np.square(se_new + se_old))/((np.square(se_new)/(n_new - 1)) + 
                                             (np.square(se_old)/(n_old - 1)))

# %%
df
# Out:
# 786.7488716114425

# %%
from scipy import stats

# %%
p = (1 - stats.t.cdf(t, df=df))

# %%
p
# Out:
# 0.4977383612564923

# %%
p < significance_level
# Out:
# False

# %% [markdown]
# Can't reject H0

# %% [markdown]
# ### MCMC Model for House Age

# %% [markdown]
# - Use MCMC to get optimal parameter for exponential distribution fit to house age

# %%
import pymc3 as pm

# %%
with pm.Model():
    #Prior
    
    lam = pm.Uniform("lam", lower=0, upper=1, testval=0.5)
    
    #Likelihood
    likelihood = pm.Exponential("likelihood", lam=lam, observed=housing_ts.HouseAge)
    
    #Posterior
    start = pm.find_MAP()
    step  = pm.Metropolis()
    trace = pm.sample(100000, njobs=3, step=step, start=start, progressbar=True)
    burned_trace = trace[3000::2]
# Out:
# logp = -27,692, ||grad|| = 12,610: 100%|██████████| 9/9 [00:00<00:00, 2681.02it/s]
# Multiprocess sampling (3 chains in 3 jobs)
# Metropolis: [lam]
# Sampling 3 chains: 100%|██████████| 301500/301500 [00:32<00:00, 9146.45draws/s]
# The number of effective samples is smaller than 10% for some parameters.

# %%
pm.traceplot(burned_trace, figsize=(16,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fbc5ef71d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fbc61ac2fd0>]],
#       dtype=object)

# %%
pm.plot_posterior(burned_trace, figsize=(16,10))

# %%
lam_posterior = np.array([point["lam"] for point in trace.points()]).mean()

# %%
1/lam_posterior # the average house age before sale assuming the data exponentially distributed
# Out:
# 36.522863197733216

# %%
from scipy import stats

# %%
plt.figure(figsize=(16,10))

plt.hist(housing_ts.HouseAge, bins=30, normed=True)
#housing_ts.HouseAge.hist(bins=30)
x = np.linspace(0, 140, 1000)
plt.plot(x, stats.expon.pdf(x, scale=1/lam_posterior))
plt.xlabel("House Age")
# Out:
# Text(0.5, 0, 'House Age')

# %% [markdown]
# - This exponential fit does an OK job of approximating the data, not great
# - Could do Chi Squared Test for goodness of fit but probably won't
#
# Look at the cumulative density function to make claims about probability of sale at certain ages:

# %%
plt.figure(figsize=(16,10))

plt.plot(x, stats.expon.cdf(x, scale=1/lam_posterior))
plt.xlabel("House Age")
plt.ylabel("CDF(X)")
# Out:
# Text(0, 0.5, 'CDF(X)')

# %% [markdown]
# - About a 40% probability that a house is sold before it is 20 years old across the entire city, given this model

# %% [markdown]
# ### Housing Type, SalePrice, Neighbourhood

# %% [markdown]
# Will, for your neighborhoods vs price vs age analysis, would you be able to look at housing type vs. Neighbourhood vs price, and square feet vs neighbourhos vs price. Just an EDA graph and a t-test?
#
# Just when I saw some neighbourhoods with way more units (eg north ames) my next question was ok...is it because thr types of houses are different and sq footage is smaller?

# %%
housing_ts.BldgType.unique()
# Out:
# array(['1Fam', '2fmCon', 'Duplex', 'TwnhsE', 'Twnhs'], dtype=object)

# %%
building_names = {"1Fam": "Single-family Detached",
                  "2fmCon": "Two-family Conversion",
                  "Duplex": "Duplex",
                  "TwnhsE": "Townhouse End Unit",
                  "Twnhs": "Townhouse Inside Unit"
                 }

housing_ts.BldgType = housing_ts.BldgType.apply(lambda x: building_names[x])

# %%
building_types = housing_ts.groupby('BldgType')

plt.figure(figsize=(16,10))
sns.barplot(building_types.Id.count().values, building_types.Id.count().index)

# %% [markdown]
# - Vast majority of buildings are Single-family homes, detached units
# - This likely won't lead to an explanation between prices in different neighbourhoods; they all mostly consist of single family homes

# %% [markdown]
# ### Basement Squared Feet, Neighbourhood, Price

# %%
plt.figure(figsize=(16,10))
housing_ts.TotalBsmtSF.hist(bins=30)

# %% [markdown]
# - Normal-like distribution around 1000sqft, there are some outliers for vastly bigger homes (6x)

# %%
plt.figure(figsize=(16,10))

plt.scatter(housing_ts.TotalBsmtSF, housing_ts.SalePrice)
plt.ylabel("Sale Price (USD)")
plt.xlabel("Total Basement Squared Feet")
# Out:
# Text(0.5, 0, 'Total Basement Squared Feet')

# %% [markdown]
# - The expected positive relationship between house size and price is evident here
# - May be some errors here with houses at 0 sqft
# - Big outlier for house at 6000 sqft

# %%
housing_ts[['TotalBsmtSF', 'SalePrice']].corr()
# Out:
#              TotalBsmtSF  SalePrice
# TotalBsmtSF     1.000000   0.613581
# SalePrice       0.613581   1.000000

# %% [markdown]
# - Moderate Positive Relationship here between the two

# %%
neighbourhood_median_sqft = housing_ts.groupby('Neighborhood').TotalBsmtSF.median()

plt.figure(figsize=(16,10))
sns.barplot(y=neighbourhood_median_sqft.index, x=neighbourhood_median_sqft)
plt.xlabel("Median Total Squared Feet", labelpad=20)
# Out:
# Text(0.5, 0, 'Median Total Squared Feet')

# %% [markdown]
# - This doesn't tell me much since it's hard to remember which places were the most pricey

# %%
neighbourhoods = housing_ts.pivot_table(index='Neighborhood', values=['SalePrice', 'TotalBsmtSF'], aggfunc='median')

# %%
neighbourhoods['Size'] = neighbourhood_size

# %%
neighbourhoods
# Out:
#                                  SalePrice  TotalBsmtSF  Size
# Neighborhood
# Bloomington Heights                 191000       1346.0    17
# Bluestem                            137500        638.5     2
# Briardale                           106000        577.5    16
# Brookside                           124300        816.0    58
# Clear Creek                         200250       1305.0    28
# College Creek                       197200       1056.0   150
# Crawford                            200624        912.0    51
# Edwards                             121750        864.0   100
# Gilbert                             181000        847.0    79
# Iowa DOT and Rail Road              103000        780.0    37
# Meadow Village                       88000        630.0    17
# Mitchell                            153500       1084.0    49
# North Ames                          140000       1026.0   225
# Northpark Villa                     146000        855.0     9
# Northridge                          301500       1338.0    41
# Northridge Heights                  315000       1582.0    77
# Northwest Ames                      182900       1142.0    73
# Old Town                            119000        789.0   113
# Sawyer                              135000        953.5    74
# Sawyer West                         179900       1050.0    59
# Somerset                            225500       1085.0    86
# South & West of Iowa State Uni.     139500        804.0    25
# Stone Brook                         278000       1494.0    25
# Timberland                          228475       1463.5    38
# Veenker                             218000       1262.0    11

# %%
plt.figure(figsize=(18,12))

for neighbourhood, color in zip(neighbourhoods.index, palette):
    
    plt.scatter(neighbourhoods.loc[neighbourhood].TotalBsmtSF,
                neighbourhoods.loc[neighbourhood].SalePrice,
                s=neighbourhoods.loc[neighbourhood].Size*10,
                c=color,
                label=neighbourhood
               )
    plt.annotate(neighbourhood,
                 (neighbourhoods.loc[neighbourhood].TotalBsmtSF,
                  neighbourhoods.loc[neighbourhood].SalePrice),
                 fontsize=12)
    
plt.title("Median Total Sqft. vs. Median Sale Price for each Neighbourhood, Sized by # of Homes", fontsize=20, pad=10)
plt.ylabel("Sale Price (USD)", labelpad=10)
plt.xlabel("Total Basement Sqft.", labelpad=10)
# Out:
# Text(0.5, 0, 'Total Basement Sqft.')

# %% [markdown]
# - There is a linear relationship between median basement sqft. and sale price when looking perThe  neighbourhood
# - Judging by the size of the dots you can see that more people live in homes that are between 800, 1200 sqft., while less live in homes that are at extremes on the spectrum
# - Northridge, Northridge Heights, Stone Brook seem to be pricey neighbourhoods with bigger homes
# - More exclusive to live in given smaller size of dots as well
#
# **This plot may help explain why including neighbourhood increases the score of our regression**

# %% [markdown]
# # NOTE: This T-Test analysis is largely useless, since the groups don't follow the assumption of normality required for the test to yield correct results. It was a bit of a stretch anyways. I don't think we can use this in our final project
#
#
# T-Test Question: Is there a statistically significant difference the price of houses in North Ames (Ames' largest neighbourhood) vs. Northridge Heights (Ames' most expensive neighbourhood with the largest homes)?HA
#
# H0: No difference between groups or North Ames mean sale price is larger<br>
# HA: The mean sales price in Northridge Heights is larger
#
# One sided T-test with significance level of 0.1

# %%
north_ames= housing_ts[housing_ts.Neighborhood == 'North Ames']
northridge_heights = housing_ts[housing_ts.Neighborhood == 'Northridge Heights']

# %%
plt.figure(figsize=(16,10))

north_ames.SalePrice.hist(bins=30, alpha=0.5, label='North Ames')
northridge_heights.SalePrice.hist(bins=30, alpha=0.5, label='Northridge Heights')

plt.legend()

# %%
plt.figure(figsize=(16,10))

plt.boxplot([north_ames.SalePrice, northridge_heights.SalePrice], labels=['North Ames', 'Northridge Heights'])
plt.show()

# %%
n_na = len(north_ames)
n_nrh = len(northridge_heights)

# %%
alpha = 0.1 # our signficance level for the t-test

# %%
na_array = np.array(north_ames.SalePrice)
nrh_array = np.array(northridge_heights.SalePrice)
na_mean = na_array.mean()
nrh_mean = nrh_array.mean()

print("Mean Sales Price for North Ames: {}\nMean Sales Price for Northridge Heights: {}".format(na_mean, nrh_mean))
# Out:
# Mean Sales Price for North Ames: 145847.08
# Mean Sales Price for Northridge Heights: 316270.6233766234

# %%
na_var = na_array.var(ddof=1)
nrh_var = nrh_array.var(ddof=1)
se_na = (na_var/n_na) #north ames
se_nrh = (nrh_var/n_nrh) # northridge heights

t = (nrh_mean - na_mean)/(se_nrh + se_na)
t
# Out:
# 0.0014123210190093492

# %%
se_nrh
# Out:
# 120669126.27000648

# %%
df = (np.square(se_nrh + se_na))/((np.square(se_nrh)/(n_nrh - 1)) + 
                                             (np.square(se_na)/(n_na - 1)))

p = (1 - stats.t.cdf(t, df=df))

# %%
df
# Out:
# 82.20265057884771

# %%
p/2
# Out:
# 0.24973001670656747

# %%
stats.ttest_ind(na_array, nrh_array, equal_var = False)
# Out:
# Ttest_indResult(statistic=-15.210856147423172, pvalue=1.2850121017015144e-25)
